# %%
from manim import *
config.set_width = "80%"
# Out:
# Manim Community v0.16.0

# %%
# %%manim -qm Test2DPlot
#
# class Test2DPlot(Scene):
#     def setup(self):
#         axes = Axes(
#             x_range=(0, 10, 2),
#             y_range=(0, 100, 20),
#             x_length=5,
#             y_length=5,
#             axis_config={
#                 "include_numbers":True,
#
#             }
#         )
#         graph = axes.plot(lambda x: x**2, x_range=[0,10])
#         self.add(axes, graph)
#         x = [i for i in range(10)]
#         dots = [Dot(axes.c2p(i, i**2), color=RED) for i in x]
#         vertical_lines = [axes.get_vertical_line(axes.c2p(i, i**2)) for i in x]
#         horizontal_lines = [axes.get_horizontal_line(axes.c2p(i, i**2)) for i in x]
#         self.add( *vertical_lines, *horizontal_lines, *dots)
# Out:
# [07/23/22 10:18:26] INFO                                                                   ]8;id=103573;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=425913;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#728\728]8;;\
#                              File ready at
#                              'D:\python\manim\manim_test\notebooks\media\images\notebooks\
#                              Test2DPlot_ManimCE_v0.16.0.png'
#                     INFO     Rendered Test2DPlot                                                       ]8;id=699960;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene.py\scene.py]8;;\:]8;id=963099;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene.py#240\240]8;;\
#                              Played 0 animations

# %%
# %%manim -qm TestNumberLine
#
# class TestNumberLine(Scene):
#     def setup(self):
#         number = NumberLine(
#             x_range=[1,10,1],
#             tick_size=3
#         )
#         self.add(number)
# Out:
# [07/23/22 14:14:37] INFO                                                                   ]8;id=765676;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=866844;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#728\728]8;;\
#                              File ready at
#                              'D:\python\manim\manim_test\notebooks\media\images\notebooks\
#                              TestNumberLine_ManimCE_v0.16.0.png'
#                     INFO     Rendered TestNumberLine                                                   ]8;id=47771;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene.py\scene.py]8;;\:]8;id=260436;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene.py#240\240]8;;\
#                              Played 0 animations

# %%
# %%manim -qm TestNumberPlane
#
# class TestNumberPlane(Scene):
#     def setup(self):
#         plane = NumberPlane(
#             background_line_style={
#                 "stroke_color":WHITE,
#                 "stroke_opacity":0.5
#             }
#         )
#         self.add(plane)
# Out:
# [07/23/22 14:27:13] INFO                                                                   ]8;id=721686;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=960428;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#728\728]8;;\
#                              File ready at
#                              'D:\python\manim\manim_test\notebooks\media\images\notebooks\
#                              TestNumberPlane_ManimCE_v0.16.0.png'
#                     INFO     Rendered TestNumberPlane                                                  ]8;id=576040;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene.py\scene.py]8;;\:]8;id=230721;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene.py#240\240]8;;\
#                              Played 0 animations

# %%
# %%manim -qm Ex1
# from common.utils import custom_range
#
# class Ex1(Scene):
#     def setup(self):
#         axes = Axes()
#         self.add(axes)
#         x_start, x_end, x_step = axes.x_range
#         y_start, y_end, y_step = axes.y_range
#         kwargs_line = {"stroke_opacity":0.5, "dash_length":0.1, "stroke_width":1}
#
#         vertical_start = [axes.c2p(i, y_start) for i in custom_range.real_range(x_start, x_end, include=[True, True])]
#         vertical_end = [axes.c2p(i, y_end) for i in custom_range.real_range(x_start, x_end, include=[True, True])]
#         vertical_line = VGroup(*[DashedLine(i,j, **kwargs_line) for i,j in zip(vertical_start, vertical_end)])
#
#         horizontal_start = [axes.c2p(x_start, i) for i in custom_range.real_range(y_start, y_end, include=[True, True])]
#         horizontal_end = [axes.c2p(x_end, i) for i in custom_range.real_range(y_start, y_end, include=[True, True])]
#         horizontal_line = VGroup(*[DashedLine(i,j, **kwargs_line) for i,j in zip(horizontal_start, horizontal_end)])
#         self.add(vertical_line, horizontal_line)
# Out:
# [07/23/22 17:00:48] INFO                                                                   ]8;id=280928;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=50099;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#728\728]8;;\
#                              File ready at
#                              'D:\python\manim\manim_test\notebooks\media\images\notebooks\
#                              Ex1_ManimCE_v0.16.0.png'
#                     INFO     Rendered Ex1                                                              ]8;id=155161;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene.py\scene.py]8;;\:]8;id=145560;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene.py#240\240]8;;\
#                              Played 0 animations

# %%
# %%manim -qm Ex2
#
# class Ex2(Scene):
#     def setup(self):
#         axis_config = {"include_numbers": True}
#         axes = Axes(
#             x_range=[-1,10,1],
#             y_range=[-1,6,1],
#             axis_config = axis_config
#         )
#         func = lambda x: 0.1 * (x - 2) * (x - 8) * (x - 5) + 3
#         plot = axes.plot(func, x_range=[0,10,0.01], use_smoothing=True, color=RED)
#         dot1 = Dot(axes.i2gp(2, plot))
#         dot2 = Dot(axes.i2gp(2.000000001, plot))
#         angle = angle_of_vector(dot2.get_center() - dot1.get_center())
#         line = Line().move_to(dot1).rotate(angle)
#         self.add(axes, plot, dot1, dot2, line)
# Out:
# [07/24/22 20:43:13] INFO                                                                   ]8;id=875148;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=990306;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#728\728]8;;\
#                              File ready at
#                              'D:\python\manim\manim_test\notebooks\media\images\notebooks\
#                              Ex2_ManimCE_v0.16.0.png'
#                     INFO     Rendered Ex2                                                              ]8;id=153774;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene.py\scene.py]8;;\:]8;id=20698;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene.py#240\240]8;;\
#                              Played 0 animations

# %%
# %%manim -qm Ex3
# import math
# from common.utils.custom_range import real_range
#
# class Ex3(Scene):
#     def setup(self):
#         self.axes = Axes(
#             x_range=[-1,13,1],
#             y_range=[-2,6,2]
#         )
#         self.graph = self.axes.plot(lambda x: math.sqrt(x), x_range=[0,13,0.01])
#         self.add(self.axes, self.graph)
#
#     def create_rectangle(self, x, smoth):
#         dl = self.axes.c2p(x,0)
#         dr = self.axes.c2p(x+smoth,0)
#         ul = self.axes.i2gp(x, self.graph)
#         ur = [dr[0], ul[1], 0]
#         return VMobject(stroke_width=0, fill_opacity=1).set_points_as_corners([dl, dr, ur, ul, dl])
#
#     def construct(self):
#         poww = [x**2.4 for x in range(2,10)]
#         smoths = [1/x for x in poww]
#         smoth = 1
#         cols = VGroup(*[self.create_rectangle(x, smoth).set_color(color=interpolate_color(YELLOW, RED, x/12)) for x in real_range(1, 12, smoth)])
#         self.add(cols)
#         self.wait()
#         for smoth in smoths:
#             new_cols = VGroup(*[self.create_rectangle(x, smoth).set_color(color=interpolate_color(YELLOW, RED, x/12)) for x in real_range(1, 12, smoth)])
#             self.play(Transform(cols, new_cols))
#             self.wait()
# Out:
# [07/24/22 21:36:41] INFO     Animation 0 : Using cached data (hash :                           ]8;id=490427;file://D:\python\manim\manim_test\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=943055;file://D:\python\manim\manim_test\lib\site-packages\manim\renderer\cairo_renderer.py#75\75]8;;\
#                              1342159004_1804042621_2938065136)
#                     INFO     Animation 1 : Partial movie file written in                   ]8;id=467876;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=408185;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#514\514]8;;\
#                              'D:\python\manim\manim_test\notebooks\media\videos\notebooks\
#                              720p30\partial_movie_files\Ex3\1353618911_2966859721_30526734
#                              33.mp4'
# [07/24/22 21:36:42] INFO     Animation 2 : Partial movie file written in                   ]8;id=469917;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=817657;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#514\514]8;;\
#                              'D:\python\manim\manim_test\notebooks\media\videos\notebooks\
#                              720p30\partial_movie_files\Ex3\1353618911_329969645_102479924
#                              .mp4'
# [07/24/22 21:36:43] INFO     Animation 3 : Partial movie file written in                   ]8;id=916707;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=669707;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#514\514]8;;\
#                              'D:\python\manim\manim_test\notebooks\media\videos\notebooks\
#                              720p30\partial_movie_files\Ex3\1353618911_356639565_312486463
#                              4.mp4'
#                     INFO     Animation 4 : Partial movie file written in                   ]8;id=424877;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=433145;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#514\514]8;;\
#                              'D:\python\manim\manim_test\notebooks\media\videos\notebooks\
#                              720p30\partial_movie_files\Ex3\1353618911_3315967912_29747657
#                              18.mp4'
# [07/24/22 21:36:45] INFO     Animation 5 : Partial movie file written in                   ]8;id=883270;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=917046;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#514\514]8;;\
#                              'D:\python\manim\manim_test\notebooks\media\videos\notebooks\
#                              720p30\partial_movie_files\Ex3\1353618911_3120194807_25889795
#                              19.mp4'
#                     INFO     Animation 6 : Partial movie file written in                   ]8;id=559111;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=660419;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#514\514]8;;\
#                              'D:\python\manim\manim_test\notebooks\media\videos\notebooks\
#                              720p30\partial_movie_files\Ex3\1353618911_3315967912_40563868
#                              93.mp4'
# [07/24/22 21:36:49] INFO     Animation 7 : Partial movie file written in                   ]8;id=789097;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=138827;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#514\514]8;;\
#                              'D:\python\manim\manim_test\notebooks\media\videos\notebooks\
#                              720p30\partial_movie_files\Ex3\1353618911_1996147318_37702316
#                              32.mp4'
# [07/24/22 21:36:50] INFO     Animation 8 : Partial movie file written in                   ]8;id=345697;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=212241;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#514\514]8;;\
#                              'D:\python\manim\manim_test\notebooks\media\videos\notebooks\
#                              720p30\partial_movie_files\Ex3\1353618911_329969645_112206609
#                              6.mp4'
# [07/24/22 21:36:58] INFO     Animation 9 : Partial movie file written in                   ]8;id=73161;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=809454;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#514\514]8;;\
#                              'D:\python\manim\manim_test\notebooks\media\videos\notebooks\
#                              720p30\partial_movie_files\Ex3\1353618911_3883554845_29948205
#                              40.mp4'
# [07/24/22 21:36:59] INFO     Animation 10 : Partial movie file written in                  ]8;id=778380;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=82011;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#514\514]8;;\
#                              'D:\python\manim\manim_test\notebooks\media\videos\notebooks\
#                              720p30\partial_movie_files\Ex3\1353618911_329969645_192193885
#                              7.mp4'
# [07/24/22 21:37:18] INFO     Animation 11 : Partial movie file written in                  ]8;id=104933;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=698166;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#514\514]8;;\
#                              'D:\python\manim\manim_test\notebooks\media\videos\notebooks\
#                              720p30\partial_movie_files\Ex3\1353618911_1626326534_25440879
#                              8.mp4'
# [07/24/22 21:37:19] INFO     Animation 12 : Partial movie file written in                  ]8;id=168077;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=247142;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#514\514]8;;\
#                              'D:\python\manim\manim_test\notebooks\media\videos\notebooks\
#                              720p30\partial_movie_files\Ex3\1353618911_3315967912_39829211
#                              0.mp4'
# [07/24/22 21:38:04] INFO     Animation 13 : Partial movie file written in                  ]8;id=740710;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=657550;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#514\514]8;;\
#                              'D:\python\manim\manim_test\notebooks\media\videos\notebooks\
#                              720p30\partial_movie_files\Ex3\1353618911_3548312772_32306968
#                              08.mp4'
# [07/24/22 21:38:06] INFO     Animation 14 : Partial movie file written in                  ]8;id=135912;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=424687;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#514\514]8;;\
#                              'D:\python\manim\manim_test\notebooks\media\videos\notebooks\
#                              720p30\partial_movie_files\Ex3\1353618911_1804042621_36712678
#                              2.mp4'
# [07/24/22 21:39:44] INFO     Animation 15 : Partial movie file written in                  ]8;id=384127;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=655149;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#514\514]8;;\
#                              'D:\python\manim\manim_test\notebooks\media\videos\notebooks\
#                              720p30\partial_movie_files\Ex3\1353618911_92505736_1641343201
#                              .mp4'
# [07/24/22 21:39:45] INFO     Animation 16 : Partial movie file written in                  ]8;id=456522;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=544028;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#514\514]8;;\
#                              'D:\python\manim\manim_test\notebooks\media\videos\notebooks\
#                              720p30\partial_movie_files\Ex3\1353618911_329969645_298918809
#                              .mp4'
#                     INFO     Combining to Movie file.                                      ]8;id=268125;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=436625;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#607\607]8;;\
# [07/24/22 21:39:46] INFO                                                                   ]8;id=213386;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=22798;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#728\728]8;;\
#                              File ready at
#                              'D:\python\manim\manim_test\notebooks\media\videos\notebooks\
#                              720p30\Ex3.mp4'
#                     INFO     The partial movie directory is full (> 100 files). Therefore, ]8;id=861227;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=769511;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#699\699]8;;\
#                              manim has removed the 9 oldest file(s). You can change this
#                              behaviour by changing max_files_cached in config.
#                     INFO     Rendered Ex3                                                              ]8;id=214544;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene.py\scene.py]8;;\:]8;id=442477;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene.py#240\240]8;;\
#                              Played 17 animations
# <video src="media\jupyter\Ex3@2022-07-24@21-39-46.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim -qm Ex4
#
# class Ex4(Scene):
#     def setup(self):
#         self.axes = Axes(
#             x_range=[-1, 10, 1],
#             y_range=[-1, 6, 1],
#             axis_config={
#                 "include_numbers":True,
#             }
#         )
#         func = lambda x: 0.1 * (x - 2) * (x - 8) * (x - 5) + 3
#         self.plot = self.axes.plot(func, x_range=[1,9, 0.05], color=RED)
#         self.add(self.axes)
#
#     def construct(self):
#         x = [i for i in range(1,10)]
#         dot = [Dot(self.axes.c2p(i,0), color=YELLOW) for i in x]
#         for i in dot:
#             i.generate_target()
#         arrow = [Arrow(i.get_center(), i.get_center()) for i in dot]
#         dot_target = [i.target.move_to(self.axes.i2gp(x[index], self.plot)) for index, i in enumerate(dot)]
#         arrow_target = [Arrow(i.get_center(), j.get_center()) for i,j in zip(dot, dot_target)]
#         self.add(*dot)
#         self.wait()
#         self.play(*[
#             Transform(i, j) for i, j in zip(dot, dot_target)
#         ], *[
#             Transform(i, j) for i, j in zip(arrow, arrow_target)
#         ], run_time=3)
#         self.play(FadeOut(*arrow))
#         self.play(Create(self.plot), run_time=3)
#         self.wait()
# Out:
# [07/24/22 22:25:36] INFO     Animation 0 : Using cached data (hash :                           ]8;id=22533;file://D:\python\manim\manim_test\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=903738;file://D:\python\manim\manim_test\lib\site-packages\manim\renderer\cairo_renderer.py#75\75]8;;\
#                              1342159004_1804042621_1702923490)
#                     INFO     Animation 1 : Using cached data (hash :                           ]8;id=321731;file://D:\python\manim\manim_test\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=40749;file://D:\python\manim\manim_test\lib\site-packages\manim\renderer\cairo_renderer.py#75\75]8;;\
#                              1353618911_2161981457_900737549)
#                     INFO     Animation 2 : Partial movie file written in                   ]8;id=952144;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=758975;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#514\514]8;;\
#                              'D:\python\manim\manim_test\notebooks\media\videos\notebooks\
#                              720p30\partial_movie_files\Ex4\1353618911_3640042972_21076017
#                              61.mp4'
# [07/24/22 22:25:37] INFO     Animation 3 : Partial movie file written in                   ]8;id=918801;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=726668;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#514\514]8;;\
#                              'D:\python\manim\manim_test\notebooks\media\videos\notebooks\
#                              720p30\partial_movie_files\Ex4\1353618911_2200376387_93473102
#                              8.mp4'
#                     INFO     Animation 4 : Partial movie file written in                   ]8;id=281107;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=32749;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#514\514]8;;\
#                              'D:\python\manim\manim_test\notebooks\media\videos\notebooks\
#                              720p30\partial_movie_files\Ex4\1353618911_3315967912_34302133
#                              86.mp4'
#                     INFO     Combining to Movie file.                                      ]8;id=712716;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=745480;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#607\607]8;;\
#                     INFO                                                                   ]8;id=97244;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=472753;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#728\728]8;;\
#                              File ready at
#                              'D:\python\manim\manim_test\notebooks\media\videos\notebooks\
#                              720p30\Ex4.mp4'
#                     INFO     The partial movie directory is full (> 100 files). Therefore, ]8;id=713262;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=122563;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#699\699]8;;\
#                              manim has removed the 3 oldest file(s). You can change this
#                              behaviour by changing max_files_cached in config.
#                     INFO     Rendered Ex4                                                              ]8;id=3218;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene.py\scene.py]8;;\:]8;id=137241;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene.py#240\240]8;;\
#                              Played 5 animations
# <video src="media\jupyter\Ex4@2022-07-24@22-25-37.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim -qm Ex5
#
# class Ex5(Scene):
#     def setup(self):
#         self.axes = Axes(
#             x_range=[-1,6,1],
#             y_range=[-1,26,1],
#             x_length=5,
#             y_length=7,
#             axis_config={
#                 "include_numbers":True,
#                 "font_size":22
#             }
#         ).shift(RIGHT*2)
#         self.graph = self.axes.plot(lambda x:x**2,x_range=[0,6,0.01])
#         self.table = MathTable(
#             [[str(i), str(i*i)] for i in range(6)],
#             include_outer_lines=True,
#             col_labels=[MathTex("x"), MathTex(r"f \left( x \right)={x}^{2}")]
#         ).scale(0.7).shift(LEFT*3+UP)
#         self.col1, self.col2 = self.table.get_columns()
#         self.col1.set_color(color=RED)
#         self.col2.set_color(color=BLUE)
#         self.table[0].remove(*self.col2[1:])
#         self.add(self.axes, self.table)
#
#     def construct(self):
#         list_f = VGroup(*[MathTex("y=", str(i),"^{2}") for i in range(6)])
#         list_f2 = VGroup(*[MathTex(str(i**2))  for i in range(6)])
#         list_point = [Dot(self.axes.i2gp(i, self.graph)) for i in range(6)]
#         list_f.next_to(self.table, DOWN)
#         list_f2.move_to(list_f[0][1])
#         self.add(list_f[0][0])
#         for i in range(6):
#             self.play(ReplacementTransform(self.col1[i+1].copy(), list_f[i][1]))
#             self.play(Write(list_f[i][2]))
#             self.play(ReplacementTransform(list_f[i][2], list_f2[i]), ReplacementTransform(list_f[i][1], list_f2[i]))
#             self.play(Transform(list_f2[i], self.col2[i+1]))
#             self.play(Transform(self.col2[i+1], list_point[i]), Transform(self.col1[i+1].co, list_point[i]))
# Out:
# [07/25/22 22:35:36] INFO     Animation 0 : Using cached data (hash :                           ]8;id=717438;file://D:\python\manim\manim_test\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=410010;file://D:\python\manim\manim_test\lib\site-packages\manim\renderer\cairo_renderer.py#75\75]8;;\
#                              1342159004_1649972376_3052661241)
# [07/25/22 22:35:37] INFO     Animation 1 : Using cached data (hash :                           ]8;id=988347;file://D:\python\manim\manim_test\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=160994;file://D:\python\manim\manim_test\lib\site-packages\manim\renderer\cairo_renderer.py#75\75]8;;\
#                              1353618911_1096162211_2434429446)
#                     INFO     Animation 2 : Using cached data (hash :                           ]8;id=144522;file://D:\python\manim\manim_test\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=433675;file://D:\python\manim\manim_test\lib\site-packages\manim\renderer\cairo_renderer.py#75\75]8;;\
#                              1353618911_1875420178_2846855781)
#                     INFO     Animation 3 : Using cached data (hash :                           ]8;id=149282;file://D:\python\manim\manim_test\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=407514;file://D:\python\manim\manim_test\lib\site-packages\manim\renderer\cairo_renderer.py#75\75]8;;\
#                              1353618911_1019061497_161894255)
# [07/25/22 22:35:38] INFO     Animation 4 : Partial movie file written in                   ]8;id=400552;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=934234;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#514\514]8;;\
#                              'D:\python\manim\manim_test\notebooks\media\videos\notebooks\
#                              720p30\partial_movie_files\Ex5\1353618911_2710226336_25682503
#                              54.mp4'
#                     INFO     Animation 5 : Partial movie file written in                   ]8;id=714187;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=352916;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#514\514]8;;\
#                              'D:\python\manim\manim_test\notebooks\media\videos\notebooks\
#                              720p30\partial_movie_files\Ex5\1353618911_2544573149_21089166
#                              33.mp4'
# [07/25/22 22:35:39] INFO     Animation 6 : Partial movie file written in                   ]8;id=737742;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=492996;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#514\514]8;;\
#                              'D:\python\manim\manim_test\notebooks\media\videos\notebooks\
#                              720p30\partial_movie_files\Ex5\1353618911_1096162211_23088220
#                              95.mp4'
#                     INFO     Animation 7 : Partial movie file written in                   ]8;id=156321;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=973852;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#514\514]8;;\
#                              'D:\python\manim\manim_test\notebooks\media\videos\notebooks\
#                              720p30\partial_movie_files\Ex5\1353618911_1921024986_24624276
#                              41.mp4'
# [07/25/22 22:35:40] INFO     Animation 8 : Partial movie file written in                   ]8;id=717893;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=727978;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#514\514]8;;\
#                              'D:\python\manim\manim_test\notebooks\media\videos\notebooks\
#                              720p30\partial_movie_files\Ex5\1353618911_2286834315_13649194
#                              81.mp4'
# [07/25/22 22:35:41] INFO     Animation 9 : Partial movie file written in                   ]8;id=606106;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=611296;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#514\514]8;;\
#                              'D:\python\manim\manim_test\notebooks\media\videos\notebooks\
#                              720p30\partial_movie_files\Ex5\1353618911_1153806272_34965682
#                              84.mp4'
#                     INFO     Animation 10 : Partial movie file written in                  ]8;id=997375;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=66171;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#514\514]8;;\
#                              'D:\python\manim\manim_test\notebooks\media\videos\notebooks\
#                              720p30\partial_movie_files\Ex5\1353618911_1077282508_14207891
#                              50.mp4'
# [07/25/22 22:35:42] INFO     Animation 11 : Partial movie file written in                  ]8;id=317684;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=854054;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#514\514]8;;\
#                              'D:\python\manim\manim_test\notebooks\media\videos\notebooks\
#                              720p30\partial_movie_files\Ex5\1353618911_2937929955_21771506
#                              17.mp4'
#                     INFO     Animation 12 : Partial movie file written in                  ]8;id=590473;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=819542;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#514\514]8;;\
#                              'D:\python\manim\manim_test\notebooks\media\videos\notebooks\
#                              720p30\partial_movie_files\Ex5\1353618911_2136745504_29280483
#                              42.mp4'
# [07/25/22 22:35:43] INFO     Animation 13 : Partial movie file written in                  ]8;id=340374;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=126145;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#514\514]8;;\
#                              'D:\python\manim\manim_test\notebooks\media\videos\notebooks\
#                              720p30\partial_movie_files\Ex5\1353618911_3319741312_26308606
#                              48.mp4'
#                     INFO     Animation 14 : Partial movie file written in                  ]8;id=977392;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=343927;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#514\514]8;;\
#                              'D:\python\manim\manim_test\notebooks\media\videos\notebooks\
#                              720p30\partial_movie_files\Ex5\1353618911_4008096941_12942961
#                              76.mp4'
# [07/25/22 22:35:44] INFO     Animation 15 : Partial movie file written in                  ]8;id=781173;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=794382;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#514\514]8;;\
#                              'D:\python\manim\manim_test\notebooks\media\videos\notebooks\
#                              720p30\partial_movie_files\Ex5\1353618911_29603013_472783338.
#                              mp4'
#                     INFO     Animation 16 : Partial movie file written in                  ]8;id=72431;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=928163;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#514\514]8;;\
#                              'D:\python\manim\manim_test\notebooks\media\videos\notebooks\
#                              720p30\partial_movie_files\Ex5\1353618911_1096162211_15377978
#                              94.mp4'
# [07/25/22 22:35:45] INFO     Animation 17 : Partial movie file written in                  ]8;id=479356;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=59918;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#514\514]8;;\
#                              'D:\python\manim\manim_test\notebooks\media\videos\notebooks\
#                              720p30\partial_movie_files\Ex5\1353618911_590042039_315943406
#                              9.mp4'
#                     INFO     Animation 18 : Partial movie file written in                  ]8;id=753148;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=809401;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#514\514]8;;\
#                              'D:\python\manim\manim_test\notebooks\media\videos\notebooks\
#                              720p30\partial_movie_files\Ex5\1353618911_1378635406_16196701
#                              03.mp4'
# [07/25/22 22:35:46] INFO     Animation 19 : Partial movie file written in                  ]8;id=527627;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=951873;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#514\514]8;;\
#                              'D:\python\manim\manim_test\notebooks\media\videos\notebooks\
#                              720p30\partial_movie_files\Ex5\1353618911_3763317384_26480026
#                              48.mp4'
# [07/25/22 22:35:47] INFO     Animation 20 : Partial movie file written in                  ]8;id=566181;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=185258;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#514\514]8;;\
#                              'D:\python\manim\manim_test\notebooks\media\videos\notebooks\
#                              720p30\partial_movie_files\Ex5\1353618911_191723898_155426410
#                              1.mp4'
#                     INFO     Animation 21 : Partial movie file written in                  ]8;id=405082;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=312974;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#514\514]8;;\
#                              'D:\python\manim\manim_test\notebooks\media\videos\notebooks\
#                              720p30\partial_movie_files\Ex5\1353618911_3630615435_42068970
#                              96.mp4'
# [07/25/22 22:35:48] INFO     Animation 22 : Partial movie file written in                  ]8;id=581412;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=743118;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#514\514]8;;\
#                              'D:\python\manim\manim_test\notebooks\media\videos\notebooks\
#                              720p30\partial_movie_files\Ex5\1353618911_1700305936_33297605
#                              04.mp4'
#                     INFO     Animation 23 : Partial movie file written in                  ]8;id=309009;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=911654;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#514\514]8;;\
#                              'D:\python\manim\manim_test\notebooks\media\videos\notebooks\
#                              720p30\partial_movie_files\Ex5\1353618911_641054237_334272808
#                              4.mp4'
# [07/25/22 22:35:49] INFO     Animation 24 : Partial movie file written in                  ]8;id=101149;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=215175;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#514\514]8;;\
#                              'D:\python\manim\manim_test\notebooks\media\videos\notebooks\
#                              720p30\partial_movie_files\Ex5\1353618911_3578471892_20186167
#                              02.mp4'
#                     INFO     Animation 25 : Partial movie file written in                  ]8;id=958625;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=941811;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#514\514]8;;\
#                              'D:\python\manim\manim_test\notebooks\media\videos\notebooks\
#                              720p30\partial_movie_files\Ex5\1353618911_2312089482_5124475.
#                              mp4'
# [07/25/22 22:35:50] INFO     Animation 26 : Partial movie file written in                  ]8;id=854699;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=963267;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#514\514]8;;\
#                              'D:\python\manim\manim_test\notebooks\media\videos\notebooks\
#                              720p30\partial_movie_files\Ex5\1353618911_1096162211_17401437
#                              35.mp4'
# [07/25/22 22:35:51] INFO     Animation 27 : Partial movie file written in                  ]8;id=988926;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=900648;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#514\514]8;;\
#                              'D:\python\manim\manim_test\notebooks\media\videos\notebooks\
#                              720p30\partial_movie_files\Ex5\1353618911_1380907108_62265978
#                              .mp4'
#                     INFO     Animation 28 : Partial movie file written in                  ]8;id=130347;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=343363;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#514\514]8;;\
#                              'D:\python\manim\manim_test\notebooks\media\videos\notebooks\
#                              720p30\partial_movie_files\Ex5\1353618911_1534415951_21086798
#                              45.mp4'
# [07/25/22 22:35:52] INFO     Animation 29 : Partial movie file written in                  ]8;id=952720;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=748152;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#514\514]8;;\
#                              'D:\python\manim\manim_test\notebooks\media\videos\notebooks\
#                              720p30\partial_movie_files\Ex5\1353618911_3801128501_38116906
#                              69.mp4'
#                     INFO     Combining to Movie file.                                      ]8;id=11902;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=519973;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#607\607]8;;\
#                     INFO                                                                   ]8;id=245180;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=330433;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#728\728]8;;\
#                              File ready at
#                              'D:\python\manim\manim_test\notebooks\media\videos\notebooks\
#                              720p30\Ex5.mp4'
#                     INFO     The partial movie directory is full (> 100 files). Therefore, ]8;id=761992;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=810299;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#699\699]8;;\
#                              manim has removed the 27 oldest file(s). You can change this
#                              behaviour by changing max_files_cached in config.
#                     INFO     Rendered Ex5                                                              ]8;id=885883;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene.py\scene.py]8;;\:]8;id=597794;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene.py#240\240]8;;\
#                              Played 30 animations
# <video src="media\jupyter\Ex5@2022-07-25@22-35-52.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>
