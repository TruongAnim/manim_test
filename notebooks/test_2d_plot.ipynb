# %%
from manim import *
config.set_width = "80%"
# Out:
# Manim Community v0.16.0

# %%
# %%manim -qm Test2DPlot
#
# class Test2DPlot(Scene):
#     def setup(self):
#         axes = Axes(
#             x_range=(0, 10, 2),
#             y_range=(0, 100, 20),
#             x_length=5,
#             y_length=5,
#             axis_config={
#                 "include_numbers":True,
#
#             }
#         )
#         graph = axes.plot(lambda x: x**2, x_range=[0,10])
#         self.add(axes, graph)
#         x = [i for i in range(10)]
#         dots = [Dot(axes.c2p(i, i**2), color=RED) for i in x]
#         vertical_lines = [axes.get_vertical_line(axes.c2p(i, i**2)) for i in x]
#         horizontal_lines = [axes.get_horizontal_line(axes.c2p(i, i**2)) for i in x]
#         self.add( *vertical_lines, *horizontal_lines, *dots)
# Out:
# [07/23/22 10:18:26] INFO                                                                   ]8;id=103573;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=425913;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#728\728]8;;\
#                              File ready at
#                              'D:\python\manim\manim_test\notebooks\media\images\notebooks\
#                              Test2DPlot_ManimCE_v0.16.0.png'
#                     INFO     Rendered Test2DPlot                                                       ]8;id=699960;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene.py\scene.py]8;;\:]8;id=963099;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene.py#240\240]8;;\
#                              Played 0 animations

# %%
# %%manim -qm TestNumberLine
#
# class TestNumberLine(Scene):
#     def setup(self):
#         number = NumberLine(
#             x_range=[1,10,1],
#             tick_size=3
#         )
#         self.add(number)
# Out:
# [07/23/22 14:14:37] INFO                                                                   ]8;id=765676;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=866844;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#728\728]8;;\
#                              File ready at
#                              'D:\python\manim\manim_test\notebooks\media\images\notebooks\
#                              TestNumberLine_ManimCE_v0.16.0.png'
#                     INFO     Rendered TestNumberLine                                                   ]8;id=47771;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene.py\scene.py]8;;\:]8;id=260436;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene.py#240\240]8;;\
#                              Played 0 animations

# %%
# %%manim -qm TestNumberPlane
#
# class TestNumberPlane(Scene):
#     def setup(self):
#         plane = NumberPlane(
#             background_line_style={
#                 "stroke_color":WHITE,
#                 "stroke_opacity":0.5
#             }
#         )
#         self.add(plane)
# Out:
# [07/23/22 14:27:13] INFO                                                                   ]8;id=721686;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=960428;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#728\728]8;;\
#                              File ready at
#                              'D:\python\manim\manim_test\notebooks\media\images\notebooks\
#                              TestNumberPlane_ManimCE_v0.16.0.png'
#                     INFO     Rendered TestNumberPlane                                                  ]8;id=576040;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene.py\scene.py]8;;\:]8;id=230721;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene.py#240\240]8;;\
#                              Played 0 animations

# %%
# %%manim -qm Ex1
# from common.utils import custom_range
#
# class Ex1(Scene):
#     def setup(self):
#         axes = Axes()
#         self.add(axes)
#         x_start, x_end, x_step = axes.x_range
#         y_start, y_end, y_step = axes.y_range
#         kwargs_line = {"stroke_opacity":0.5, "dash_length":0.1, "stroke_width":1}
#
#         vertical_start = [axes.c2p(i, y_start) for i in custom_range.real_range(x_start, x_end, include=[True, True])]
#         vertical_end = [axes.c2p(i, y_end) for i in custom_range.real_range(x_start, x_end, include=[True, True])]
#         vertical_line = VGroup(*[DashedLine(i,j, **kwargs_line) for i,j in zip(vertical_start, vertical_end)])
#
#         horizontal_start = [axes.c2p(x_start, i) for i in custom_range.real_range(y_start, y_end, include=[True, True])]
#         horizontal_end = [axes.c2p(x_end, i) for i in custom_range.real_range(y_start, y_end, include=[True, True])]
#         horizontal_line = VGroup(*[DashedLine(i,j, **kwargs_line) for i,j in zip(horizontal_start, horizontal_end)])
#         self.add(vertical_line, horizontal_line)
# Out:
# [07/23/22 17:00:48] INFO                                                                   ]8;id=280928;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=50099;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#728\728]8;;\
#                              File ready at
#                              'D:\python\manim\manim_test\notebooks\media\images\notebooks\
#                              Ex1_ManimCE_v0.16.0.png'
#                     INFO     Rendered Ex1                                                              ]8;id=155161;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene.py\scene.py]8;;\:]8;id=145560;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene.py#240\240]8;;\
#                              Played 0 animations

# %%
# %%manim -qm Ex2
#
# class Ex2(Scene):
#     def setup(self):
#         axis_config = {"include_numbers": True}
#         axes = Axes(
#             x_range=[-1,10,1],
#             y_range=[-1,6,1],
#             axis_config = axis_config
#         )
#         func = lambda x: 0.1 * (x - 2) * (x - 8) * (x - 5) + 3
#         plot = axes.plot(func, x_range=[0,10], color=RED)
#         dot1 = Dot(axes.i2gp(2, plot))
#         dot2 = Dot(axes.i2gp(2.000000001, plot))
#         angle = angle_of_vector(dot2.get_center() - dot1.get_center())
#         line = Line().move_to(dot1).rotate(angle)
#         self.add(axes, plot, dot1, dot2, line)
# Out:
# [07/23/22 22:23:34] INFO                                                                   ]8;id=499232;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=584584;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#728\728]8;;\
#                              File ready at
#                              'D:\python\manim\manim_test\notebooks\media\images\notebooks\
#                              Ex2_ManimCE_v0.16.0.png'
#                     INFO     Rendered Ex2                                                              ]8;id=636838;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene.py\scene.py]8;;\:]8;id=842124;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene.py#240\240]8;;\
#                              Played 0 animations
