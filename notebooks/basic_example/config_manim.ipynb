# %%
from manim import *
# Out:
# Manim Community v0.16.0

# %%
config.media_width = "100%"
config.media_embed = True

# %%
# %%manim -qm -v WARNING -c config.cfg TestScene
#
# class TestScene(Scene):
#     def setup(self):
#         pass
