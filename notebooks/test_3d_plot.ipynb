# %%
from manim import *
config.set_width = "80%"
# Out:
# Manim Community v0.16.0

# %%
# %%manim -qm Ex1
#
# class Ex1(ThreeDScene):
#     def setup(self):
#         pass
#
#     def construct(self):
#
#         self.set_camera_orientation(phi=70*DEGREES,theta=-120*DEGREES)
#
#
#
#         axes = ThreeDAxes(x_range=(-5, 5, 1), y_range=(-5, 5, 1), z_range=(-5, 5, 1))
#
#         surface = Surface(
#
#             lambda u, v: axes.c2p(u, v, 2 * np.sin(u) * np.cos(v)),
#
#             resolution=(42, 42),
#
#             v_range=[-5, 5],
#
#             u_range=[-5, 5],
#
#         )
#
#         surface.fade(0.5)
#
#         self.add(axes,surface)
# Out:
# [07/27/22 09:59:23] INFO                                                                   ]8;id=564459;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=714403;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#728\728]8;;\
#                              File ready at
#                              'D:\python\manim\manim_test\notebooks\media\images\notebooks\
#                              TestThreeD_ManimCE_v0.16.0.png'
#                     INFO     Rendered TestThreeD                                                       ]8;id=129118;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene.py\scene.py]8;;\:]8;id=48106;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene.py#240\240]8;;\
#                              Played 0 animations

# %%
# %%manim -qm TestThreeD
#
# class TestThreeD(ThreeDScene):
#     def setup(self):
#         three_d = ThreeDAxes()
#         self.add(three_d)
# Out:
# [07/27/22 10:00:40] INFO                                                                   ]8;id=798379;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=789746;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#728\728]8;;\
#                              File ready at
#                              'D:\python\manim\manim_test\notebooks\media\images\notebooks\
#                              TestThreeD_ManimCE_v0.16.0.png'
#                     INFO     Rendered TestThreeD                                                       ]8;id=37786;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene.py\scene.py]8;;\:]8;id=714665;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene.py#240\240]8;;\
#                              Played 0 animations
