# %%
from manim import *
config.set_width = "80%"
# Out:
# Manim Community v0.16.0

# %%
# %%manim -qm Ex1
# from common.utils.color_utils import interpolate_color_range
#
# class Ex1(ThreeDScene):
#     def setup(self):
#         pass
#
#     def construct(self):
#
#         self.set_camera_orientation(phi=70*DEGREES,theta=-120*DEGREES)
#
#
#
#         axes = ThreeDAxes(x_range=(-5, 5, 1), y_range=(-5, 5, 1), z_range=(-5, 5, 1))
#
#         surface = Surface(
#
#             lambda u, v: axes.c2p(u, v, 2 * np.sin(u) * np.cos(v)),
#
#             resolution=(45, 45),
#
#             v_range=[-5, 5],
#
#             u_range=[-5, 5],
#
#         )
#
#         surface.fade(0.5)
#         colors = [DARK_BLUE, YELLOW, RED]
#         partical = surface.submobjects
#         for i in partical:
#             y = i.get_top()[2]
#             i.set_color(interpolate_color_range(*colors, (y+1)/2.5))
#         self.add(axes,surface)
# Out:
# [07/27/22 15:00:39] INFO                                                                   ]8;id=801569;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=789105;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#728\728]8;;\
#                              File ready at
#                              'D:\python\manim\manim_test\notebooks\media\images\notebooks\
#                              Ex1_ManimCE_v0.16.0.png'
#                     INFO     Rendered Ex1                                                              ]8;id=704122;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene.py\scene.py]8;;\:]8;id=381619;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene.py#240\240]8;;\
#                              Played 0 animations

# %%
# %%manim -qm Ex2
# from common.utils.color_utils import interpolate_color_range
#
# resolution = 42
# class Ex2(ThreeDScene):
#     def setup(self):
#         self.set_camera_orientation(phi = 0.4*PI, theta = 1.3*PI)
#         self.three_d_axes = ThreeDAxes(x_range=(-5, 5, 1), y_range=(-5, 5, 1), z_range=(-5, 5, 1))
#         self.surface = Surface(
#             lambda u,v: self.three_d_axes.c2p(u,v,0),
#             u_range=[-5,5],
#             v_range=[-5,5],
#             resolution=(resolution,resolution),
#             stroke_color=YELLOW,
#             checkerboard_colors=[YELLOW]
#         )
#         self.add(self.three_d_axes)
#
#     def construct(self):
#         self.play(LaggedStart(*[DrawBorderThenFill(i) for i in self.surface], lag_ratio=0.005, run_time=5))
#
#         surface = Surface(
#             lambda u, v: self.three_d_axes.c2p(u, v, 2 * np.sin(u) * np.cos(v)),
#             resolution=(resolution, resolution),
#             v_range=[-5, 5],
#             u_range=[-5, 5],
#         )
#         surface.fade(0.5)
#         colors = [DARK_BLUE, YELLOW, RED]
#         partical = surface.submobjects
#         for i in partical:
#             y = i.get_top()[2]
#             i.set_color(interpolate_color_range(*colors, (y+1)/2.5))
#
#         self.wait()
#         self.play(Transform (self.surface, surface), run_time=5)
#         self.wait()
# Out:
# [07/27/22 16:39:38] INFO     Animation 0 : Partial movie file written in                   ]8;id=609323;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=219470;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#514\514]8;;\
#                              'D:\python\manim\manim_test\notebooks\media\videos\notebooks\
#                              720p30\partial_movie_files\Ex2\1074470925_1036805928_32422312
#                              74.mp4'
# [07/27/22 16:40:31] INFO     Animation 1 : Using cached data (hash :                           ]8;id=578933;file://D:\python\manim\manim_test\lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=378098;file://D:\python\manim\manim_test\lib\site-packages\manim\renderer\cairo_renderer.py#75\75]8;;\
#                              2233803653_3315967912_2003307802)
# [07/27/22 16:43:24] INFO     Animation 2 : Partial movie file written in                   ]8;id=175128;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=778499;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#514\514]8;;\
#                              'D:\python\manim\manim_test\notebooks\media\videos\notebooks\
#                              720p30\partial_movie_files\Ex2\2233803653_2937099953_19665284
#                              45.mp4'
# [07/27/22 16:43:27] INFO     Animation 3 : Partial movie file written in                   ]8;id=776996;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=814298;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#514\514]8;;\
#                              'D:\python\manim\manim_test\notebooks\media\videos\notebooks\
#                              720p30\partial_movie_files\Ex2\2233803653_3315967912_35907413
#                              26.mp4'
#                     INFO     Combining to Movie file.                                      ]8;id=325161;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=688578;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#607\607]8;;\
#                     INFO                                                                   ]8;id=335114;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=838739;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#728\728]8;;\
#                              File ready at
#                              'D:\python\manim\manim_test\notebooks\media\videos\notebooks\
#                              720p30\Ex2.mp4'
#                     INFO     Rendered Ex2                                                              ]8;id=719024;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene.py\scene.py]8;;\:]8;id=347084;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene.py#240\240]8;;\
#                              Played 4 animations
# <video src="media\jupyter\Ex2@2022-07-27@16-43-27.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim -qm TestThreeD
#
# class TestThreeD(ThreeDScene):
#     def setup(self):
#         self.set_camera_orientation(phi = 0.4*PI, theta=1.7*PI, gamma=0*PI)
#         three_d = ThreeDAxes()
#         self.add(three_d)
# Out:
# [07/27/22 14:41:57] INFO                                                                   ]8;id=648342;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=441709;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#728\728]8;;\
#                              File ready at
#                              'D:\python\manim\manim_test\notebooks\media\images\notebooks\
#                              TestThreeD_ManimCE_v0.16.0.png'
#                     INFO     Rendered TestThreeD                                                       ]8;id=111505;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene.py\scene.py]8;;\:]8;id=254805;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene.py#240\240]8;;\
#                              Played 0 animations

# %%
# %%manim -qm Example
#
# class Example(ThreeDScene):
#     def construct(self):
#         axes_3d = ThreeDAxes()
#         func = axes_3d.plot_parametric_curve(
#             lambda t: np.array([
#                 2*np.cos(t),
#                 3*np.sin(t),
#                 t/3
#             ]),
#             t_range=(-2*PI,2*PI,0.01),
#             color=RED
#         )
#
#         self.set_camera_orientation(phi=70*DEGREES,theta=240*DEGREES)
#         self.add(
#             axes_3d,
#             func
#         )
#         self.wait(0.5)
#         self.move_camera(theta=120*DEGREES,run_time=6,rate_func=linear)
#         self.wait(0.5)
#         self.move_camera(theta=90*DEGREES,phi=0,run_time=2,rate_func=smooth)
#         self.wait(0.5)
# Out:
# [07/28/22 05:55:22] INFO     Animation 0 : Partial movie file written in                   ]8;id=172127;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=543761;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#514\514]8;;\
#                              'D:\python\manim\manim_test\notebooks\media\videos\notebooks\
#                              720p30\partial_movie_files\Example\4175500016_2644758854_1516
#                              178951.mp4'
# [07/28/22 05:55:47] INFO     Animation 1 : Partial movie file written in                   ]8;id=133392;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=809031;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#514\514]8;;\
#                              'D:\python\manim\manim_test\notebooks\media\videos\notebooks\
#                              720p30\partial_movie_files\Example\2439941205_906006558_26340
#                              81073.mp4'
# [07/28/22 05:55:48] INFO     Animation 2 : Partial movie file written in                   ]8;id=633114;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=881370;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#514\514]8;;\
#                              'D:\python\manim\manim_test\notebooks\media\videos\notebooks\
#                              720p30\partial_movie_files\Example\427781673_645682970_679297
#                              996.mp4'
# [07/28/22 05:55:56] INFO     Animation 3 : Partial movie file written in                   ]8;id=646948;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=869991;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#514\514]8;;\
#                              'D:\python\manim\manim_test\notebooks\media\videos\notebooks\
#                              720p30\partial_movie_files\Example\129548083_656520363_340890
#                              3731.mp4'
# [07/28/22 05:55:57] INFO     Animation 4 : Partial movie file written in                   ]8;id=880222;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=817789;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#514\514]8;;\
#                              'D:\python\manim\manim_test\notebooks\media\videos\notebooks\
#                              720p30\partial_movie_files\Example\509456135_2526496290_12379
#                              97865.mp4'
#                     INFO     Combining to Movie file.                                      ]8;id=226957;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=402355;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#607\607]8;;\
#                     INFO                                                                   ]8;id=292359;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=919325;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#728\728]8;;\
#                              File ready at
#                              'D:\python\manim\manim_test\notebooks\media\videos\notebooks\
#                              720p30\Example.mp4'
#                     INFO     Rendered Example                                                          ]8;id=216368;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene.py\scene.py]8;;\:]8;id=986122;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene.py#240\240]8;;\
#                              Played 5 animations
# <video src="media\jupyter\Example@2022-07-28@05-55-57.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim -qm Example
#
# class Example(ThreeDScene):
#     def construct(self):
#         axes_3d = ThreeDAxes(
#             x_range=(-6,6,1),
#             x_length=12,
#             y_range=(-5,5,1),
#             y_length=10,
#             z_range=(-3,3,1),
#             z_length=6,
#         )
#         self.set_camera_orientation(phi=70*DEGREES,theta=240*DEGREES)
#
#         surface = Surface(
#             lambda u, v: np.array([
#                 np.cos(TAU * v),
#                 np.sin(TAU * v),
#                 2 * (1 - u)
#             ]),
#         ).fade(0.5)
#
#         paraboloid = Surface(
#             lambda u, v: np.array([
#                 np.cos(v)*u,
#                 np.sin(v)*u,
#                 u**2
#             ]),
#             v_range=(0,TAU),
#         ).fade(0.5)
#
#         para_hyp = Surface(
#             lambda u, v: np.array([
#                 u,
#                 v,
#                 u**2-v**2
#             ]),
#             u_range=(-2,2),
#             v_range=(-2,2),
#         ).fade(0.5)
#
#         cone = Surface(
#             lambda u, v: np.array([
#                 u*np.cos(v),
#                 u*np.sin(v),
#                 u
#             ]),
#             u_range=(-2,2),
#             v_range=(0,TAU),
#         )
#         sphere = Surface(
#             lambda u, v: np.array([
#                 1.5*np.cos(u)*np.cos(v),
#                 1.5*np.cos(u)*np.sin(v),
#                 1.5*np.sin(u)
#             ]),
#             #Resolution of the surfaces
#             u_range=(-PI/2,PI/2),
#             v_range=(0,TAU),
#         )
#
#         self.add(
#             axes_3d,surface
#         )
#         self.play(
#             Transform(surface, paraboloid)
#         )
#         self.wait(0.5)
#         self.play(
#             Transform(surface, para_hyp)
#         )
#         self.wait(0.5)
#         self.play(
#             Transform(surface, cone)
#         )
#         self.wait(0.5)
#         self.play(
#             Transform(surface, sphere)
#         )
#         self.wait(0.5)
# Out:
# [07/28/22 05:59:39] INFO     Animation 0 : Partial movie file written in                   ]8;id=972527;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=102778;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#514\514]8;;\
#                              'D:\python\manim\manim_test\notebooks\media\videos\notebooks\
#                              720p30\partial_movie_files\Example\4175500016_3840354139_2761
#                              52181.mp4'
# [07/28/22 05:59:41] INFO     Animation 1 : Partial movie file written in                   ]8;id=981194;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=704518;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#514\514]8;;\
#                              'D:\python\manim\manim_test\notebooks\media\videos\notebooks\
#                              720p30\partial_movie_files\Example\2007058732_2526496290_1088
#                              362650.mp4'
# [07/28/22 06:00:03] INFO     Animation 2 : Partial movie file written in                   ]8;id=702121;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=284937;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#514\514]8;;\
#                              'D:\python\manim\manim_test\notebooks\media\videos\notebooks\
#                              720p30\partial_movie_files\Example\2007058732_1037294187_3083
#                              415866.mp4'
# [07/28/22 06:00:05] INFO     Animation 3 : Partial movie file written in                   ]8;id=298609;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=90642;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#514\514]8;;\
#                              'D:\python\manim\manim_test\notebooks\media\videos\notebooks\
#                              720p30\partial_movie_files\Example\2007058732_2526496290_8150
#                              67658.mp4'
# [07/28/22 06:00:28] INFO     Animation 4 : Partial movie file written in                   ]8;id=390256;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=582999;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#514\514]8;;\
#                              'D:\python\manim\manim_test\notebooks\media\videos\notebooks\
#                              720p30\partial_movie_files\Example\2007058732_3969792793_2073
#                              873089.mp4'
# [07/28/22 06:00:30] INFO     Animation 5 : Partial movie file written in                   ]8;id=393221;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=374792;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#514\514]8;;\
#                              'D:\python\manim\manim_test\notebooks\media\videos\notebooks\
#                              720p30\partial_movie_files\Example\2007058732_2526496290_6682
#                              50665.mp4'
# [07/28/22 06:00:52] INFO     Animation 6 : Partial movie file written in                   ]8;id=941584;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=916762;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#514\514]8;;\
#                              'D:\python\manim\manim_test\notebooks\media\videos\notebooks\
#                              720p30\partial_movie_files\Example\2007058732_3929821733_1368
#                              304639.mp4'
# [07/28/22 06:00:54] INFO     Animation 7 : Partial movie file written in                   ]8;id=508932;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=808287;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#514\514]8;;\
#                              'D:\python\manim\manim_test\notebooks\media\videos\notebooks\
#                              720p30\partial_movie_files\Example\2007058732_645682970_13502
#                              32940.mp4'
#                     INFO     Combining to Movie file.                                      ]8;id=7300;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=842776;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#607\607]8;;\
#                     INFO                                                                   ]8;id=5312;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=584628;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#728\728]8;;\
#                              File ready at
#                              'D:\python\manim\manim_test\notebooks\media\videos\notebooks\
#                              720p30\Example.mp4'
#                     INFO     Rendered Example                                                          ]8;id=290046;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene.py\scene.py]8;;\:]8;id=944836;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene.py#240\240]8;;\
#                              Played 8 animations
# <video src="media\jupyter\Example@2022-07-28@06-00-54.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim -qm --fps=15 --disable_caching -v WARNING Example
#
# class Example(ThreeDScene):
#     def construct(self):
#         axes_3d = ThreeDAxes(
#             # unit_size=1 in Z axis
#             z_range=(-3,3,1),
#             z_length=6,
#         )
#         self.set_camera_orientation(phi=70*DEGREES,theta=240*DEGREES)
#         # Arrows3Ds are surfaces, so the more you add, the longer it will take to render.
#         main_line        = Arrow3D(ORIGIN,axes_3d.c2p(4,3)+2*OUT,color=GREEN,height=0.7,base_radius=0.2)
#         vertical_line    = Arrow3D(axes_3d.c2p(4,0),axes_3d.c2p(4,3))
#         horizontal_line  = Arrow3D(axes_3d.c2p(0,3),axes_3d.c2p(4,3))
#         fall_line        = Arrow3D(axes_3d.c2p(4,3),axes_3d.c2p(4,3)+OUT*2)
#
#         self.add(axes_3d)
#         # start camera movement
#         self.begin_ambient_camera_rotation(0.15)
#         self.wait()
#         self.play(FadeIn(main_line))
#         self.play(FadeIn(vertical_line),FadeIn(horizontal_line),FadeIn(fall_line))
#         self.wait()
#         # stop camera movement
#         self.stop_ambient_camera_rotation()
#         self.wait()
# Out:
# <video src="media\jupyter\Example@2022-07-28@07-58-29.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim -qm Example
#
# class Example(ThreeDScene):
#     def construct(self):
#         self.set_camera_orientation(phi=70*DEGREES,theta=-120*DEGREES)
#
#         axes = ThreeDAxes(x_range=(-2, 2, 1), y_range=(-2, 2, 1), z_range=(-2, 2, 1))
#
#         surface = Surface(
#             lambda u, v: axes.c2p(u, v, 2 * np.sin(u) * np.cos(v)),
#             resolution=31,
#             v_range=[-1.5, 1.5],
#             u_range=[-1.5, 1.5],
#             checkerboard_colors = [RED,BLUE,ORANGE,YELLOW]
#         )
#         surface.fade(0.5)
#         from itertools import cycle
#         colors = cycle([RED,BLUE,ORANGE,YELLOW])
#         for s in surface: s.set_color(next(colors))
#
#         self.add(axes,surface)
# Out:
# [07/28/22 08:26:51] INFO                                                                   ]8;id=411348;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=666539;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#728\728]8;;\
#                              File ready at
#                              'D:\python\manim\manim_test\notebooks\media\images\notebooks\
#                              Example_ManimCE_v0.16.0.png'
#                     INFO     Rendered Example                                                          ]8;id=529380;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene.py\scene.py]8;;\:]8;id=472758;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene.py#240\240]8;;\
#                              Played 0 animations
