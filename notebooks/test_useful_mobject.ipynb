# %%
from manim import *
config.set_width = "80%"
# Out:
# Manim Community v0.16.0

# %%
# %%manim -qm TestCodeFromFile
#
# class TestCodeFromFile(Scene):
#     def setup(self):
#         code = Code(file_name="hello_world.cpp", font="Monospace")
#         self.add(code)
# Out:
# [07/18/22 20:40:45] INFO                                                                   ]8;id=307879;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=87310;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#728\728]8;;\
#                              File ready at
#                              'D:\python\manim\manim_test\notebooks\media\images\notebooks\
#                              TestCodeFromFile_ManimCE_v0.16.0.png'
#                     INFO     Rendered TestCodeFromFile                                                 ]8;id=103467;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene.py\scene.py]8;;\:]8;id=140108;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene.py#240\240]8;;\
#                              Played 0 animations

# %%
# %%manim -ql TestCodeFromString
#
# class TestCodeFromString(Scene):
#     def setup(self):
#         hello_world = '''\
#             #include <iostream>
#             using namespace std;
#
#             int main(){
#                 cout<<"hello world"<<endl;
#
#                 return 0;
#             }'''
#         code = Code(code=hello_world, font="Monospace", language="cpp")
#         self.add(code)
# Out:
# [07/18/22 22:33:54] INFO                                                                   ]8;id=227446;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=613817;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#728\728]8;;\
#                              File ready at
#                              'D:\python\manim\manim_test\notebooks\media\images\notebooks\
#                              TestCodeFromString_ManimCE_v0.16.0.png'
#                     INFO     Rendered TestCodeFromString                                               ]8;id=828840;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene.py\scene.py]8;;\:]8;id=474820;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene.py#240\240]8;;\
#                              Played 0 animations

# %%
# %%manim -ql HighlightCode
#
# class HighlightCode(Scene):
#     def setup(self):
#         hello_world = '''\
#             #include <iostream>
#             using namespace std;
#
#             int main(){
#                 cout<<"hello world"<<endl;
#
#                 return 0;
#             }'''
#         self.code = Code(code=hello_world, font="Monospace", language="cpp")
#         self.add(self.code)
#
#     def construct(self):
#         list_highlight = [
#             (0,),
#             (3,4),
#             (6,)
#         ]
#         def get_line(i):
#             print(i)
#             return self.code[1][i]
#
#         def create_highlight(lines):
#             print(lines)
#             up = get_line(lines[0]).get_top()
#             down = get_line(lines[-1]).get_bottom()
#             left = get_line(lines[0]).get_left()
#             right = self.code[2].get_right()
#             UL_ = [left[0], up[1], 0]
#             UR_ = [right[0], up[1], 0]
#             DL_ = [left[0], down[1], 0]
#             DR_ = [right[0], down[1], 0]
#
#             kwargs = {"fill_color":YELLOW, "fill_opacity":0.3, "stroke_width":0}
#             return VMobject(**kwargs).set_points_as_corners([UL_, UR_, DR_, DL_]).scale(1.1)
#         pre = None
#         for index, item in enumerate(list_highlight):
#             highlight = create_highlight(item)
#             if index==0:
#                 self.play(FadeIn(highlight))
#             else:
#                 self.play(ReplacementTransform(pre, highlight))
#             pre = highlight
#             self.wait()
# Out:
# (0,)
# 0
# 0
# 0
# [07/18/22 23:03:52] INFO     Animation 0 : Partial movie file written in                   ]8;id=643805;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=54617;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#514\514]8;;\
#                              'D:\python\manim\manim_test\notebooks\media\videos\notebooks\
#                              480p15\partial_movie_files\HighlightCode\3163782288_225087238
#                              7_3747712.mp4'
# [07/18/22 23:03:53] INFO     Animation 1 : Partial movie file written in                   ]8;id=389141;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=27257;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#514\514]8;;\
#                              'D:\python\manim\manim_test\notebooks\media\videos\notebooks\
#                              480p15\partial_movie_files\HighlightCode\2201830969_329969645
#                              _3079110995.mp4'
# (3, 4)
# 3
# 4
# 3
#                     INFO     Animation 2 : Partial movie file written in                   ]8;id=782864;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=356317;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#514\514]8;;\
#                              'D:\python\manim\manim_test\notebooks\media\videos\notebooks\
#                              480p15\partial_movie_files\HighlightCode\2201830969_294268215
#                              6_2045821921.mp4'
# [07/18/22 23:03:54] INFO     Animation 3 : Partial movie file written in                   ]8;id=367504;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=404552;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#514\514]8;;\
#                              'D:\python\manim\manim_test\notebooks\media\videos\notebooks\
#                              480p15\partial_movie_files\HighlightCode\2201830969_329969645
#                              _1916419071.mp4'
# (6,)
# 6
# 6
# 6
#                     INFO     Animation 4 : Partial movie file written in                   ]8;id=828332;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=915464;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#514\514]8;;\
#                              'D:\python\manim\manim_test\notebooks\media\videos\notebooks\
#                              480p15\partial_movie_files\HighlightCode\2201830969_230826544
#                              6_2503742728.mp4'
# [07/18/22 23:03:55] INFO     Animation 5 : Partial movie file written in                   ]8;id=527273;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=722127;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#514\514]8;;\
#                              'D:\python\manim\manim_test\notebooks\media\videos\notebooks\
#                              480p15\partial_movie_files\HighlightCode\2201830969_329969645
#                              _2637685054.mp4'
#                     INFO     Combining to Movie file.                                      ]8;id=915266;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=751369;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#607\607]8;;\
#                     INFO                                                                   ]8;id=800754;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=797637;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene_file_writer.py#728\728]8;;\
#                              File ready at
#                              'D:\python\manim\manim_test\notebooks\media\videos\notebooks\
#                              480p15\HighlightCode.mp4'
#                     INFO     Rendered HighlightCode                                                    ]8;id=991065;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene.py\scene.py]8;;\:]8;id=734491;file://D:\python\manim\manim_test\lib\site-packages\manim\scene\scene.py#240\240]8;;\
#                              Played 6 animations
# <video src="media\jupyter\HighlightCode@2022-07-18@23-03-55.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>
